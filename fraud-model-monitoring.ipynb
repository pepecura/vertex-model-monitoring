# %% [markdown]
# #### Build a basic model monitoring flow on Vertex AI.
# 1. Deploy the endpoint in the GUI and set the model monitoring settings (with 1 hour granularity).
# 2. Run the predictions on the endpoint using a dataset different than the training.
# 3. Review the output results in the GUI.
#
# This notebook will handle the tasks in Step#2.

# %%
# Set parameters.
PROJECT_ID    = "bonibon"
PROJECT       = "991126484363"
LOCATION      = "us-central1"
ENDPOINT_ID   = "6201245580656640"
ENDPOINT_NAME = "projects/"+PROJECT_ID+"/locations/"+LOCATION+"/endpoints/"+ENDPOINT_ID
print(ENDPOINT_NAME)
# Out:
# projects/bonibon/locations/us-central1/endpoints/6201245580656640

# %%
# Install packages and restart kernel.
#!pip3 install --user --upgrade --quiet kfp google-cloud-pipeline-components
#!pip3 install jsonlines

# %%
# Import packages.
import json
from google.cloud import aiplatform
from google_cloud_pipeline_components import aiplatform as gcc_aip
from kfp.v2.google.client import AIPlatformClient

# %%
# Create endpoint handler.
endpoint = aiplatform.Endpoint(endpoint_name= ENDPOINT_NAME)

# %%
# Generate a sample instance.
instance ={"amount": "157277.00", "amountError": "0.00", "destzeroFlag":"0", 
          "nameDest":"C214774813", "nameOrig": "C2108616891", "newbalanceDest": "688015.98",
          "newbalanceOrig":"0.00", "oldbalanceDest":"451217.28", "oldbalanceOrig":"109.00", 
          "origzeroFlag":"0","type":"TRANSFER"}

# %%
# Call the model and get the prediction.
response = endpoint.predict([instance])
print('API response: ', response)
# Out:
# API response:  Prediction(predictions=[{'scores': [0.9999849200248718, 1.502110626461217e-05], 'classes': ['0', '1']}], deployed_model_id='6485121890762358784', explanations=None)

# %% [markdown]
# #### Read a BigQuery table as jsonl file for endpoint prediction.
# https://cloud.google.com/bigquery/docs/samples/bigquery-extract-table-json#bigquery_extract_table_json-python

# %%
# Convert the scoring table in BigQuery into jsonl format.

from google.cloud import bigquery
client = bigquery.Client()
bucket_name = 'bonibon-bucket/fraud/data'
project= "bonibon"
dataset_id = "finance"
table_id = "fraud_data_test_42"

destination_uri = "gs://{}/{}".format(bucket_name, "fraud_data_test_42_debug.json")
dataset_ref = bigquery.DatasetReference(project, dataset_id)
table_ref = dataset_ref.table(table_id)
job_config = bigquery.job.ExtractJobConfig()
job_config.destination_format = bigquery.DestinationFormat.NEWLINE_DELIMITED_JSON

extract_job = client.extract_table(
    table_ref,
    destination_uri,
    job_config=job_config,
    # Location must match that of the source table.
    location="US",
)  # API request
extract_job.result()  # Waits for job to complete.
# Out:
# ExtractJob<project=bonibon, location=US, id=e9f803a6-c8d5-41e7-9df4-d9a0718278b5>

# %% [markdown]
# ### Manual process in between:
# 1. replace all ": with ":"
# 2. replace all ," with ","
# 3. replace all "" with "
# 4. replace all } with },
# 5. insert { "instances":[ at the beginning
# 6. delete , at the end
# 7. insert ]} at the end.

# %%
import gcsfs
import json

gcs_file_system = gcsfs.GCSFileSystem(project="bonibon")
gcs_json_path = "gs://bonibon-bucket/fraud/data/fraud_data_test_42.json"
with gcs_file_system.open(gcs_json_path) as f:
    json_dict = json.load(f)

# %%
json_dict["instances"][1]
# Out:
# {'type': 'CASH_OUT',
#  'amount': '43248.02',
#  'nameOrig': 'C1309678931',
#  'nameDest': 'C190273303',
#  'oldbalanceOrig': '0',
#  'newbalanceOrig': '0',
#  'oldbalanceDest': '1161575.08',
#  'newbalanceDest': '1150434.65',
#  'origzeroFlag': '1',
#  'destzeroFlag': '0',
#  'amountError': '-54388',
#  'id': '375cad75-62d6-479f-8698-0f82d4594b35',
#  'isFraud': '0'}

# %%
response = endpoint.predict(json_dict['instances'])
print('API response: ', response)
# Out:
# API response:  Prediction(predictions=[{'scores': [0.9999670386314392, 3.291038228780963e-05], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9999715089797974, 2.849611337296665e-05]}, {'classes': ['0', '1'], 'scores': [0.9999891519546509, 1.08322974483599e-05]}, {'classes': ['0', '1'], 'scores': [0.9999313354492188, 6.870587094454095e-05]}, {'scores': [0.9999747276306152, 2.524153751437552e-05], 'classes': ['0', '1']}, {'scores': [0.9998142719268799, 0.0001857527531683445], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9999818205833435, 1.817058000597171e-05]}, {'scores': [0.9999066591262817, 9.332695481134579e-05], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9999927878379822, 7.147853011701955e-06]}, {'classes': ['0', '1'], 'scores': [0.9999866485595703, 1.337242883892031e-05]}, {'classes': ['0', '1'], 'scores': [0.9999499320983887, 4.998077565687709e-05]}, {'classes': ['0', '1'], 'scores': [0.9999490976333618, 5.085906377644278e-05]}, {'classes': ['0', '1'], 'scores': [0.999993622303009, 6.344688245008001e-06]}, {'classes': ['0', '1'], 'scores': [0.9999874830245972, 1.242455527972197e-05]}, {'scores': [0.9999821186065674, 1.799368692445569e-05], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.999938428401947, 6.160623888717964e-05]}, {'classes': ['0', '1'], 'scores': [0.9999366402626038, 6.333322380669415e-05]}, {'classes': ['0', '1'], 'scores': [0.9999765753746033, 2.349458191019949e-05]}, {'scores': [0.999954879283905, 4.509748760028742e-05], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9999887347221375, 1.125026665249607e-05]}, {'classes': ['0', '1'], 'scores': [0.9999700784683228, 2.986770050483756e-05]}, {'classes': ['0', '1'], 'scores': [0.9999868273735046, 1.308500759478193e-05]}, {'classes': ['0', '1'], 'scores': [0.9999619126319885, 3.806302993325517e-05]}, {'classes': ['0', '1'], 'scores': [0.9999796748161316, 2.016373218793888e-05]}, {'scores': [0.9999900460243225, 9.942642464011442e-06], 'classes': ['0', '1']}, {'scores': [0.9999818205833435, 1.809267814678606e-05], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9999555945396423, 4.437111056176946e-05]}, {'classes': ['0', '1'], 'scores': [0.9999845623970032, 1.546953353681602e-05]}, {'classes': ['0', '1'], 'scores': [0.9999882578849792, 1.179860373667907e-05]}, {'classes': ['0', '1'], 'scores': [0.9999556541442871, 4.431914567248896e-05]}, {'scores': [0.9997645616531372, 0.0002354600437683985], 'classes': ['0', '1']}, {'scores': [0.999983549118042, 1.644537587708328e-05], 'classes': ['0', '1']}, {'scores': [0.9999877214431763, 1.225578307639807e-05], 'classes': ['0', '1']}, {'scores': [0.9999485611915588, 5.136680556461215e-05], 'classes': ['0', '1']}, {'scores': [0.9998354911804199, 0.00016445477376692], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9999521970748901, 4.776137939188629e-05]}, {'classes': ['0', '1'], 'scores': [0.9999768137931824, 2.319591840205248e-05]}, {'scores': [0.9999311566352844, 6.883735477458686e-05], 'classes': ['0', '1']}, {'scores': [0.9999862313270569, 1.382609298161697e-05], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9999808073043823, 1.913271626108326e-05]}, {'scores': [0.9999919533729553, 8.08099503046833e-06], 'classes': ['0', '1']}, {'classes': ['0', '1'], 'scores': [0.9962350726127625, 0.00376487011089921]}], deployed_model_id='6485121890762358784', explanations=None)

# %% [markdown]
# #### Get online predictions and explanations with AutoML model.
# https://cloud.google.com/vertex-ai/docs/predictions/online-predictions-automl#tabular

# %%
def predict_tabular_classification_sample(
    project: str, location: str, endpoint: str, instances: List[Dict],
):
    aiplatform.init(project=project, location=location)
    endpoint = aiplatform.Endpoint(endpoint)
    response = endpoint.predict(instances=instances)
    for prediction_ in response.predictions:
        print(prediction_)
predict_tabular_classification_sample(
    project= PROJECT_ID, location= LOCATION, endpoint=ENDPOINT_ID, instances=json_dict['instances'])
# Out:
# {'scores': [0.9999670386314392, 3.291038228780963e-05], 'classes': ['0', '1']}
# {'scores': [0.9999715089797974, 2.849611337296665e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999891519546509, 1.08322974483599e-05]}
# {'scores': [0.9999313354492188, 6.870587094454095e-05], 'classes': ['0', '1']}
# {'scores': [0.9999747276306152, 2.524153751437552e-05], 'classes': ['0', '1']}
# {'scores': [0.9998142719268799, 0.0001857527531683445], 'classes': ['0', '1']}
# {'scores': [0.9999818205833435, 1.817058000597171e-05], 'classes': ['0', '1']}
# {'scores': [0.9999066591262817, 9.332695481134579e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999927878379822, 7.147853011701955e-06]}
# {'classes': ['0', '1'], 'scores': [0.9999866485595703, 1.337242883892031e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999499320983887, 4.998077565687709e-05]}
# {'scores': [0.9999490976333618, 5.085906377644278e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.999993622303009, 6.344688245008001e-06]}
# {'scores': [0.9999874830245972, 1.242455527972197e-05], 'classes': ['0', '1']}
# {'scores': [0.9999821186065674, 1.799368692445569e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.999938428401947, 6.160623888717964e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999366402626038, 6.333322380669415e-05]}
# {'scores': [0.9999765753746033, 2.349458191019949e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.999954879283905, 4.509748760028742e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999887347221375, 1.125026665249607e-05]}
# {'scores': [0.9999700784683228, 2.986770050483756e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999868273735046, 1.308500759478193e-05]}
# {'scores': [0.9999619126319885, 3.806302993325517e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999796748161316, 2.016373218793888e-05]}
# {'scores': [0.9999900460243225, 9.942642464011442e-06], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999818205833435, 1.809267814678606e-05]}
# {'scores': [0.9999555945396423, 4.437111056176946e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999845623970032, 1.546953353681602e-05]}
# {'scores': [0.9999882578849792, 1.179860373667907e-05], 'classes': ['0', '1']}
# {'scores': [0.9999556541442871, 4.431914567248896e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9997645616531372, 0.0002354600437683985]}
# {'scores': [0.999983549118042, 1.644537587708328e-05], 'classes': ['0', '1']}
# {'scores': [0.9999877214431763, 1.225578307639807e-05], 'classes': ['0', '1']}
# {'scores': [0.9999485611915588, 5.136680556461215e-05], 'classes': ['0', '1']}
# {'scores': [0.9998354911804199, 0.00016445477376692], 'classes': ['0', '1']}
# {'scores': [0.9999521970748901, 4.776137939188629e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999768137931824, 2.319591840205248e-05]}
# {'scores': [0.9999311566352844, 6.883735477458686e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999862313270569, 1.382609298161697e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999808073043823, 1.913271626108326e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999919533729553, 8.08099503046833e-06]}
# {'classes': ['0', '1'], 'scores': [0.9962350726127625, 0.00376487011089921]}

# %%
def explain_tabular_sample(
    project: str, location: str, endpoint_id: str, instance_dict: Dict
):

    aiplatform.init(project=project, location=location)
    endpoint = aiplatform.Endpoint(endpoint_id)
    response = endpoint.explain(instances=instance_dict, parameters={})

    for explanation in response.explanations:
        print(" explanation")
        # Feature attributions.
        attributions = explanation.attributions
        for attribution in attributions:
            print("  attribution")
            print("   baseline_output_value:", attribution.baseline_output_value)
            print("   instance_output_value:", attribution.instance_output_value)
            print("   output_display_name:", attribution.output_display_name)
            print("   approximation_error:", attribution.approximation_error)
            print("   output_name:", attribution.output_name)
            output_index = attribution.output_index
            for output_index in output_index:
                print("   output_index:", output_index)

    for prediction in response.predictions:
        print(prediction)

explain_tabular_sample(
    project= PROJECT_ID, location= LOCATION, endpoint_id=ENDPOINT_ID, instance_dict=json_dict['instances'])
# Out:
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999670386314392
#    output_display_name: 0
#    approximation_error: 0.004377420551748184
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999715089797974
#    output_display_name: 0
#    approximation_error: 0.004310389851002913
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999891519546509
#    output_display_name: 0
#    approximation_error: 0.003701794978196038
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999313354492188
#    output_display_name: 0
#    approximation_error: 0.005088619095662969
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999747276306152
#    output_display_name: 0
#    approximation_error: 0.0034659355933191836
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9998142719268799
#    output_display_name: 0
#    approximation_error: 0.004615253020465795
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999818205833435
#    output_display_name: 0
#    approximation_error: 0.004600274804144512
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999066591262817
#    output_display_name: 0
#    approximation_error: 0.0038447173619991027
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999927878379822
#    output_display_name: 0
#    approximation_error: 0.004926404385161434
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999866485595703
#    output_display_name: 0
#    approximation_error: 0.004210425887016208
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999499320983887
#    output_display_name: 0
#    approximation_error: 0.004312321620986542
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999490976333618
#    output_display_name: 0
#    approximation_error: 0.003765756989810057
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.999993622303009
#    output_display_name: 0
#    approximation_error: 0.004367459571067276
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999874830245972
#    output_display_name: 0
#    approximation_error: 0.0035516686808658372
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999821186065674
#    output_display_name: 0
#    approximation_error: 0.004503119064618589
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.999938428401947
#    output_display_name: 0
#    approximation_error: 0.004410338193422856
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999366402626038
#    output_display_name: 0
#    approximation_error: 0.004571990564018937
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999765753746033
#    output_display_name: 0
#    approximation_error: 0.00484379813740113
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.999954879283905
#    output_display_name: 0
#    approximation_error: 0.003953792787569761
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999887347221375
#    output_display_name: 0
#    approximation_error: 0.005193539652495688
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999700784683228
#    output_display_name: 0
#    approximation_error: 0.007996136502413344
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999868273735046
#    output_display_name: 0
#    approximation_error: 0.004393961155918288
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999619126319885
#    output_display_name: 0
#    approximation_error: 0.00497503060388477
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999796748161316
#    output_display_name: 0
#    approximation_error: 0.004135134673052825
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999900460243225
#    output_display_name: 0
#    approximation_error: 0.005196444864307165
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999818205833435
#    output_display_name: 0
#    approximation_error: 0.004223095101511287
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999555945396423
#    output_display_name: 0
#    approximation_error: 0.003807190049095932
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999845623970032
#    output_display_name: 0
#    approximation_error: 0.0037663887543607525
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999882578849792
#    output_display_name: 0
#    approximation_error: 0.0037430308125796377
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999556541442871
#    output_display_name: 0
#    approximation_error: 0.003888082058046407
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9997645616531372
#    output_display_name: 0
#    approximation_error: 0.003976053986981199
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.999983549118042
#    output_display_name: 0
#    approximation_error: 0.003979356084044716
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999877214431763
#    output_display_name: 0
#    approximation_error: 0.004930632470632152
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999485611915588
#    output_display_name: 0
#    approximation_error: 0.004553311259914558
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9998354911804199
#    output_display_name: 0
#    approximation_error: 0.004497264759391219
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999521970748901
#    output_display_name: 0
#    approximation_error: 0.004243264129334599
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999768137931824
#    output_display_name: 0
#    approximation_error: 0.004060033359233897
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999311566352844
#    output_display_name: 0
#    approximation_error: 0.00569697289229105
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999862313270569
#    output_display_name: 0
#    approximation_error: 0.004081481030119842
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999808073043823
#    output_display_name: 0
#    approximation_error: 0.0034700568743320616
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9999919533729553
#    output_display_name: 0
#    approximation_error: 0.0053682972217453375
#    output_name: scores
#    output_index: 0
#  explanation
#   attribution
#    baseline_output_value: 0.9999698996543884
#    instance_output_value: 0.9962350726127625
#    output_display_name: 0
#    approximation_error: 0.006798809724172431
#    output_name: scores
#    output_index: 0
# {'classes': ['0', '1'], 'scores': [0.9999670386314392, 3.291038228780963e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999715089797974, 2.849611337296665e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999891519546509, 1.08322974483599e-05]}
# {'scores': [0.9999313354492188, 6.870587094454095e-05], 'classes': ['0', '1']}
# {'scores': [0.9999747276306152, 2.524153751437552e-05], 'classes': ['0', '1']}
# {'scores': [0.9998142719268799, 0.0001857527531683445], 'classes': ['0', '1']}
# {'scores': [0.9999818205833435, 1.817058000597171e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999066591262817, 9.332695481134579e-05]}
# {'scores': [0.9999927878379822, 7.147853011701955e-06], 'classes': ['0', '1']}
# {'scores': [0.9999866485595703, 1.337242883892031e-05], 'classes': ['0', '1']}
# {'scores': [0.9999499320983887, 4.998077565687709e-05], 'classes': ['0', '1']}
# {'scores': [0.9999490976333618, 5.085906377644278e-05], 'classes': ['0', '1']}
# {'scores': [0.999993622303009, 6.344688245008001e-06], 'classes': ['0', '1']}
# {'scores': [0.9999874830245972, 1.242455527972197e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999821186065674, 1.799368692445569e-05]}
# {'scores': [0.999938428401947, 6.160623888717964e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999366402626038, 6.333322380669415e-05]}
# {'scores': [0.9999765753746033, 2.349458191019949e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.999954879283905, 4.509748760028742e-05]}
# {'scores': [0.9999887347221375, 1.125026665249607e-05], 'classes': ['0', '1']}
# {'scores': [0.9999700784683228, 2.986770050483756e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999868273735046, 1.308500759478193e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999619126319885, 3.806302993325517e-05]}
# {'scores': [0.9999796748161316, 2.016373218793888e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999900460243225, 9.942642464011442e-06]}
# {'classes': ['0', '1'], 'scores': [0.9999818205833435, 1.809267814678606e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999555945396423, 4.437111056176946e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999845623970032, 1.546953353681602e-05]}
# {'scores': [0.9999882578849792, 1.179860373667907e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999556541442871, 4.431914567248896e-05]}
# {'classes': ['0', '1'], 'scores': [0.9997645616531372, 0.0002354600437683985]}
# {'scores': [0.999983549118042, 1.644537587708328e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999877214431763, 1.225578307639807e-05]}
# {'scores': [0.9999485611915588, 5.136680556461215e-05], 'classes': ['0', '1']}
# {'scores': [0.9998354911804199, 0.00016445477376692], 'classes': ['0', '1']}
# {'scores': [0.9999521970748901, 4.776137939188629e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999768137931824, 2.319591840205248e-05]}
# {'scores': [0.9999311566352844, 6.883735477458686e-05], 'classes': ['0', '1']}
# {'classes': ['0', '1'], 'scores': [0.9999862313270569, 1.382609298161697e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999808073043823, 1.913271626108326e-05]}
# {'classes': ['0', '1'], 'scores': [0.9999919533729553, 8.08099503046833e-06]}
# {'classes': ['0', '1'], 'scores': [0.9962350726127625, 0.00376487011089921]}

# %% [markdown]
# ##### End of file.
